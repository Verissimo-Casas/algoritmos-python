# %% [markdown]
# 1. Escreva um algoritmo que armazene 3 dados sobre você: **Nome, Idade e Cidade Natal**. Apresente os dados na tela com a seguinte formação:
#
# *   "Meu nome é **Nome**, tenho **Idade** anos e nasci na cidade de **Cidade Natal!

# %%
nome = "Veríssimo"
idade = 25
cidade = "Manaus"

print("Meu nome é " + nome,", tenho " + idade, "nos e nasci na cidade de " + cidade, end="!")
# Out:
# Digite seu nome: Veríssimo
# Digite sua idade: 25
# Digite sua cidade natal: Manaus
# Meu nome é Veríssimo , tenho 25 nos e nasci na cidade de Manaus!

# %% [markdown]
# 2. Escreva um algoritmo que receba um valor e seu expoente depois mostre o resultado.

# %%
base = int(input("Digite a base: "))
expoente = int(input("Digite o expoente: "))

resultado = base ** expoente

print(f"Rsultado: {resultado}")
# Out:
# Digite a base: 2
# Digite o expoente: 2
# 4

# %% [markdown]
# 3. Escreva um algortimo que receba 3 nomes de frutas e mostre os dados separados com "-" (hifém).

# %%
fruta1 = input("Digite o nome da primeira fruta: ")
fruta2 = input("Digite o nome da segunda fruta: ")
fruta3 = input("Digite o nome da terceira fruta: ")

print(fruta1 + "-" + fruta2 + "-" + fruta3)

# %% [markdown]
# 4. Faça um algoritmo que peça as 4 notas bimestrais e mostre a média.

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))

media = (nota1 + nota2 + nota3 + nota4) / 4

print(f"Média: {media}")

# %% [markdown]
# 5. Faça um Programa que peça a temperatura em graus Farenheit, transforme e mostre a temperatura em graus Celsius.
#
# ![FtoCformula3.jpg](data:image/jpeg;base64,...)

# %%
Farenheit = float(input("Digite a temperatura em Farenheit: "))
Celsius = round((Farenheit - 32) * 5/9, 2)

print("A temperatura em Celsius é: ", Celsius)
# Out:
# Digite a temperatura em Farenheit: 40
# A temperatura em Celsius é:  4.44

# %% [markdown]
# 6. Faça um Programa que pergunte quanto você ganha por hora e o número de horas
# trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valor_hora = float(input("Digite o valor da sua hora: "))
horas_trabalhadas = float(input("Digite as horas trabalhadas no mês: " ))

salario = valor_hora * horas_trabalhadas

print("O seu salário no mês é: ", salario)

# %% [markdown]
# 7. Escreva um algoritmo para ler as dimensões de um retângulo (base e altura), calcular e escrever a área do retângulo.

# %%
base = float(input("Digite a base do retângulo: "))
altura = float(input("Digite a altura do retângulo: "))

area = base * altura

print("A área do retângulo é: ", area)

# %% [markdown]
# 8. Escreva um algoritmo que receba um valor do usuário e depois mostre o valor e o tipo da informação que foi inserida (int, float, complex, string...).

# %%
  variavel = input("Digite um valor: ")

  print(f"Variavel digitada: {variavel}, seu tipo eh {tipo}.")
# Out:
# Digite um valor: 4
# Variavel digitada: 4, seu tipo eh Int.
